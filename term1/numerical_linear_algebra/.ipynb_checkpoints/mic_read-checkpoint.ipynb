# %%
#import ipdb
MFC = {}

def hash_fft_coeff(e):    
    if e in MFC:
        return MFC[e]
    else:
        return 1

def amplify(array_data):
    N = array_data.shape[0]
    result = np.zeros(N)
    yf = np.fft.fft(array_data)
    dt = 1. / 1024
    xf = np.linspace(0.0, 1.0/(2.0 * dt), N / 2)
    podgonion = np.hstack((np.repeat(0.75, N/2), np.ones(N/2)))
    result = np.fft.ifft(np.asarray([yf[i]*podgonion[i] for i in range(N)]))
    return np.int32(result)
    
    
    

    for i, e in enumerate(f_d):
        result[i] = hash_fft_coeff(e)
    
    return result

# %%
import pyaudio as pa
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

CHUNK = 128
FORMAT = pa.paInt32
CHANNELS = 1
RATE = 44100

# print(CHUNK / RATE)

papa = pa.PyAudio()

stream = papa.open(format=FORMAT, channels=CHANNELS, rate=RATE, input=True, output=True, frames_per_buffer=CHUNK)

print("* recording")

g = []

while True:
    data = stream.read(CHUNK)
    array_data = np.fromstring(data, np.int32)

    amplified_signal = amplify(array_data)

    result = -1 * amplified_signal
    
    stream.write(result.tobytes())
    
    
print("* done recording")

stream.terminate()
# Out:
# * recording
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:18: ComplexWarning: Casting complex values to real discards the imaginary part
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-be3e81b4765e> in <module>()
#      21
#      22 while True:
# ---> 23     data = stream.read(CHUNK)
#      24     array_data = np.fromstring(data, np.int32)
#      25
#
# //anaconda/lib/python2.7/site-packages/pyaudio.pyc in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:

# %%
import pyaudio as pa
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

CHUNK = 128
FORMAT = pa.paInt32
CHANNELS = 1
RATE = 44100

# print(CHUNK / RATE)

papa = pa.PyAudio()

stream = papa.open(format=FORMAT, channels=CHANNELS, rate=RATE, input=True, output=True, frames_per_buffer=CHUNK)

print("* recording")

g = []

while True:
    data = stream.read(CHUNK)
    array_data = np.fromstring(data, np.int32)
#     fft_data = np.fft.fft(array_data)
#     result = np.fft.ifft(fft_data * np.exp(-np.pi * 1j / 2))
#     result = (np.absolute(result) * np.sign(np.imag(result))).astype(np.int16)
#     coeff = build_coeff(array_data)
#     result = -1 * coeff * array_data
#     g.append(array_data)
    result = -1 * array_data
    
    stream.write(result.tobytes())
    

    
print("* done recording")
# Out:
# * recording
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e26d22e8ab91> in <module>()
#      21
#      22 while True:
# ---> 23     data = stream.read(CHUNK)
#      24     array_data = np.fromstring(data, np.int32)
#      25 #     fft_data = np.fft.fft(array_data)
#
# //anaconda/lib/python2.7/site-packages/pyaudio.pyc in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:

# %%
array_data.shape[0]
# Out:
# 256

# %%
plt.plot(array_data)
plt.plot(result)
plt.plot(result + array_data)

# %%
i = np.arange(1, 10240 / 2)
g1 = np.sin(2 * np.pi * 5 * i / 1024)
g2 = np.sin(2 * np.pi * 15 * i / 1024)
plt.plot(g1)
plt.plot(g2)
plt.plot(g1 + g2)

# %%
yf = np.fft.fft(g1 + g2)
dt = 1.0 / 1024
xf = np.linspace(0.0, 1.0/(2.0*dt), 1024/2)
plt.plot(xf, 2.0/1024 * np.abs(yf[0:1024/2]))

# %%
N = 1024
dt = 1./800
x = np.linspace(0.0, N*dt, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x) + 0.2*np.sin(300.0 * 2.0*np.pi*x)
freq = np.fft.fftfreq(y.shape[-1], d=dt)
yf = np.fft.fft(y)
xf = np.linspace(0.0, 1.0/(2.0*dt), N/2)
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e0d31ce7faf> in <module>()
#       1 N = 1024
#       2 dt = 1./800
# ----> 3 x = np.linspace(0.0, N*dt, N)
#       4 y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x) + 0.2*np.sin(300.0 * 2.0*np.pi*x)
#       5 freq = np.fft.fftfreq(y.shape[-1], d=dt)
#
# NameError: name 'np' is not defined

# %%
import pyaudio
import wave
import time
import numpy as np
CHUNK_SIZE = 5
FORMAT = pyaudio.paInt16
RATE = 44100

p = pyaudio.PyAudio()
stream = p.open(format=FORMAT, channels=1, rate=RATE,
input=True, output=True,
frames_per_buffer=CHUNK_SIZE)
print(stream.get_input_latency(), stream.get_output_latency())
p.terminate()
